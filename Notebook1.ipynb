# %%
x = 3
y = 4
print(x + y)
# Out:
# 7

# %%
#convert str to int
price_str = "10.55"
price_int = (price_str)
print(price_int)
# Out:
# 10.55

# %%
my_list = [1,2,3,4,5]
my_set = set(my_list)

print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
#convert str to float
price_str = "80"
price_float =(price_str)
print (price_float)
# Out:
# 80

# %%
#convert float to int
price_int = "10.78"
price_int = (price_float)
print (price_int)
# Out:
# 80
